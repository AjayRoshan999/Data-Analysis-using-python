# %%
import requests
api_key='b247b87c00a94dbaa0c53821242802'
city=input("Enter any city :")
url=f'http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}'
response=requests.get(url)
data=response.json()
if response.status_code ==200:
  print("City :",data['location']['name'])
  print("State :",data['location']['region'])
  print("Country :",data['location']['country'])
  print("Temperature (in c) :",data['current']['temp_c'])
  print("feels like :",data['current']['feelslike_c'])
  print("wind speed (in mph) :",data['current']['wind_mph'])
  print("wind direction :",data['current']['wind_dir'])
  print("humidity :",data['current']['humidity'])
else:
  print("City not found")
# Out:
# Enter any city :huih
# City : Huihuixtla
# State : Veracruz-Llave
# Country : Mexico
# Temperature (in c) : 22.3
# feels like : 24.7
# wind speed (in mph) : 5.4
# wind direction : S
# humidity : 88

# %%
type(data)
# Out:
# dict

# %%
print("City :",data['location']['name'])
# Out:
# City : Chennai

# %%
print("City :",data['location']['name'])
print("State :",data['location']['region'])
print("Country :",data['location']['country'])
print("Temperature (in c) :",data['current']['temp_c'])
print("feels like :",data['current']['feelslike_c'])
print("wind speed (in mph) :",data['current']['wind_mph'])
print("wind direction :",data['current']['wind_dir'])
print("humidity :",data['current']['humidity'])
# Out:
# City : Chennai
# State : Tamil Nadu
# Country : India
# Temperature (in c) : 31.0
# feels like : 34.3
# wind speed (in mph) : 9.4
# wind direction : ENE
# humidity : 66
