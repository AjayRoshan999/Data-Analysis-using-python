# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Clean_Thyroid Detection.csv")

# %%
df
# Out:
#       age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0      41   F            f                  f                         f    f
# 1      23   F            f                  f                         f    f
# 2      46   M            f                  f                         f    f
# 3      70   F            t                  f                         f    f
# 4      70   F            f                  f                         f    f
# ...   ...  ..          ...                ...                       ...  ...
# 3766   30   F            f                  f                         f    f
# 3767   68   F            f                  f                         f    f
# 3768   74   F            f                  f                         f    f
# 3769   72   M            f                  f                         f    f
# 3770   64   F            f                  f                         f    f
#
# ...

# %%
from sklearn.linear_model import LinearRegression
LR =LinearRegression()
