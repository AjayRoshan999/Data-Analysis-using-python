# %%
import pandas as pd

# %%
a=['ajay','raju','venky','prem','ravi','loki','thor']
r=pd.Series(a,index=[1,2,3,4,5,6,7])
print(r)
# Out:
# 1     ajay
# 2     raju
# 3    venky
# 4     prem
# 5     ravi
# 6     loki
# 7     thor
# dtype: object

# %%
a=['ajay','raju','venky','prem','ravi','loki','thor']
l=[1,2,3,4,5,6,7]
r=pd.Series(a,index=l)
print(r)
# Out:
# 1     ajay
# 2     raju
# 3    venky
# 4     prem
# 5     ravi
# 6     loki
# 7     thor
# dtype: object

# %%
#loading csv
dia=pd.read_csv('/content/diabetcsv.csv')
dia
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
grade=pd.read_csv('/content/grades.txt')
grade
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade
# 0                  Joe K 9.8 10 9.9 A+
# 1               Rajesh M 8.9 9.1 9.3 A
# 2               Kissan V 9.9 9.3 9.2 A
# 3                   Mary N 7.7 8 7.1 B
# 4                Jeen K 9.8 9.1 9.9 A+
# 5                  Raj M 8.9 9.1 9.3 A
# 6                 Hassan V 9.9 9 9.2 A
# 7                   Mari N 7.7 8 7.1 B
# 8                Jess K 9.8 9.1 9.9 A+
# 9                 Rajini M 7 9.1 9.3 A
# 10               Kiran V 9.9 9.3 9.2 A
# 11                  Maya N 7.7 8 7.1 B
# 12              Jolin K 9.8 9.1 9.9 A+
# 13                  Riya M 8 9.1 9.3 A
# 14                Sana V 9.9 9.3 9.2 A
# 15                    Mark N 7.7 8 7 B

# %%
demodt=pd.read_csv('/content/demodt.txt')
demodt
# Out:
#    State  Literacy  Cleanliness  Crime_Rate  Good
# 0      A        92           90          54     0
# 1      B        56           67          50     1
# 2      C        78           85          62     0
# 3      D        63           72          48     1
# 4      E        85           79          55     0
# 5      F        71           68          58     0
# 6      G        80           83          51     0
# 7      H        67           74          47     1
# 8      I        89           88          53     0
# 9      J        58           65          49     1
# 10     K        82           81          60     0
# 11     L        75           78          57     0
# 12     M        69           70          46     1
# 13     N        87           86          52     0
# 14     O        61           63          45     1
# 15     P        93           91          56     0
# 16     Q        55           66          61     0
# 17     R        76           77          59     0
# ...

# %%
diaxl=pd.read_excel('/content/diaxl.xlsx')
diaxl
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
diaxl=pd.read_excel('/content/diaxl.xlsx',sheet_name='dora')
diaxl
# Out:
#   Dead Alive
# 0  yes    no
# 1  yes    no
# 2  yes    no
# 3  yes    no
# 4  yes    no

# %%
diaxl.describe()
# Out:
#        Dead Alive
# count     5     5
# unique    1     1
# top     yes    no
# freq      5     5

# %%
print(grade.shape)
# Out:
# (16, 1)

# %%
gwn=pd.read_csv('/content/grades_withnulls.txt')
gwn
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                       Joe K 9.8 10 9.9 A+ 1
# 1                   Rajesh M 8.9 9.1 9.3 A 1
# 2                     Kissan V 9.9 9.8 10 A 0
# 3                        Mary N 7.7 8 NaN B 0
# 4                     Jeen K 9.8 9.1 9.9 A+ 1
# 5                       Raj M 8.9 9.1 9.3 A 1
# 6                      Hassan V 9.9 9 9.2 A 1
# 7                        Mari N 7.7 8 7.1 B 1
# 8                     Jess K NaN 9.1 9.9 A+ 1
# 9                    Rajini M NaN 9.1 9.3 A 0
# 10                    Kiran V NaN 9.3 9.2 A 0
# 11                       Maya N 7.7 8 7.1 B 0
# 12                   Jolin K 9.8 9.1 9.9 A+ 1
# 13                   Rajesh M 8.9 9.1 9.3 A 1
# 14                      Riya M 9.3 9.9 10 A 1
# 15                     Sana V 9.9 9.3 9.2 A 0
# 16                         Mark N 7.7 8 7 B 0

# %%
print(gwn.isnull().sum())
# Out:
# Names Initials SEM1 SEM2 SEM3 Grade Placed    0
# dtype: int64

# %%
df=pd.read_csv('/content/grades_withnulls.csv')
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
print(df.shape)
# Out:
# (17, 7)

# %%
print(df.isnull())
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
print(df.isnull().sum)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# ...

# %%
print(df.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
df1=df.dropna()
df1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df1.dropna(inplace=True)
# Out:
# <ipython-input-28-e0e758ddcf8a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.dropna(inplace=True)

# %%
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df2=pd.read_csv('/content/grades_withnulls.csv')
df2.fillna(555,inplace=True)
df2
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  555.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  555.0   9.1    9.9    A+       1
# 9   Rajini        M  555.0   9.1    9.3     A       0
# 10   Kiran        V  555.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 13  Rajesh        M    8.9   9.1    9.3     A       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# ...

# %%
df3=pd.read_csv('/content/grades_withnulls.csv')
mean=df3['SEM1'].mean()
print(mean)
df3.fillna(mean,inplace=True)
df3
# Out:
# 8.992857142857144
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
#Access the data
#iloc=integer location,index
#loc=field names,index
#dfname.loc[index]----->rows
#
df3.loc[0]
# Out:
# Names        Joe
# Initials       K
# SEM1         9.8
# SEM2        10.0
# SEM3         9.9
# Grade         A+
# Placed         1
# Name: 0, dtype: object

# %%
df3.loc[8:14]
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 8     Jess        K  8.992857   9.1   9.9    A+       1
# 9   Rajini        M  8.992857   9.1   9.3     A       0
# 10   Kiran        V  8.992857   9.3   9.2     A       0
# 11    Maya        N  7.700000   8.0   7.1     B       0
# 12   Jolin        K  9.800000   9.1   9.9    A+       1
# 13  Rajesh        M  8.900000   9.1   9.3     A       1
# 14    Riya        M  9.300000   9.9  10.0     A       1

# %%
df3.loc[5:7,'SEM1']
# Out:
# 5    8.9
# 6    9.9
# 7    7.7
# Name: SEM1, dtype: float64

# %%
df3.iloc[10:12,0:3]
# Out:
#     Names Initials      SEM1
# 10  Kiran        V  8.992857
# 11   Maya        N  7.700000

# %%
df3[df3.SEM2==9.1]
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M  8.900000   9.1   9.3     A       1
# 4     Jeen        K  9.800000   9.1   9.9    A+       1
# 5      Raj        M  8.900000   9.1   9.3     A       1
# 8     Jess        K  8.992857   9.1   9.9    A+       1
# 9   Rajini        M  8.992857   9.1   9.3     A       0
# 12   Jolin        K  9.800000   9.1   9.9    A+       1
# 13  Rajesh        M  8.900000   9.1   9.3     A       1

# %%
#print the records who scored 9.3 in sem3
df3[df3.SEM3==9.3]
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M  8.900000   9.1   9.3     A       1
# 5      Raj        M  8.900000   9.1   9.3     A       1
# 9   Rajini        M  8.992857   9.1   9.3     A       0
# 13  Rajesh        M  8.900000   9.1   9.3     A       1

# %%
df3.loc[df3['SEM1']>9.8, 'Names']
# Out:
# 2     Kissan
# 6     Hassan
# 15      Sana
# Name: Names, dtype: object

# %%
#print the grades of students who scored more than 9.7 in sem3
df3.loc[df3.SEM3>9.7,'Grade']
# Out:
# 0     A+
# 2      A
# 4     A+
# 8     A+
# 12    A+
# 14     A
# Name: Grade, dtype: object

# %%
df3
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
df3.drop_duplicates()
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 14    Riya        M  9.300000   9.9  10.000000     A       1
# ...

# %%
df3.head(7)
# Out:
#     Names Initials  SEM1  SEM2       SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.900000    A+       1
# 1  Rajesh        M   8.9   9.1   9.300000     A       1
# 2  Kissan        V   9.9   9.8  10.000000     A       0
# 3    Mary        N   7.7   8.0   8.992857     B       0
# 4    Jeen        K   9.8   9.1   9.900000    A+       1
# 5     Raj        M   8.9   9.1   9.300000     A       1
# 6  Hassan        V   9.9   9.0   9.200000     A       1

# %%
print(df3[df3.index==5])
print(df3.loc[df3.index==5,'Grade'])
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 5   Raj        M   8.9   9.1   9.3     A       1
# 5    A
# Name: Grade, dtype: object

# %%
#create a new column average with average value of sem1 ,sem2,sem3
df3['Average']=(df3['SEM1']+df3['SEM2']+df3['SEM3'])/3
df3
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed   Average
# 0      Joe        K  9.800000  10.0   9.900000    A+       1  9.900000
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1  9.100000
# 2   Kissan        V  9.900000   9.8  10.000000     A       0  9.900000
# 3     Mary        N  7.700000   8.0   8.992857     B       0  8.230952
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1  9.600000
# 5      Raj        M  8.900000   9.1   9.300000     A       1  9.100000
# 6   Hassan        V  9.900000   9.0   9.200000     A       1  9.366667
# 7     Mari        N  7.700000   8.0   7.100000     B       1  7.600000
# 8     Jess        K  8.992857   9.1   9.900000    A+       1  9.330952
# 9   Rajini        M  8.992857   9.1   9.300000     A       0  9.130952
# 10   Kiran        V  8.992857   9.3   9.200000     A       0  9.164286
# 11    Maya        N  7.700000   8.0   7.100000     B       0  7.600000
# ...

# %% [markdown]
# # Plotting with Panda

# %%
df3['SEM1'].plot.line()
# Out:
# <Axes: >

# %%
df3[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
df3[['SEM1','SEM2']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
df3.plot(kind='scatter',x='Average',y='Names')
# Out:
# <Axes: xlabel='Average', ylabel='Names'>

# %%
df3.plot(kind='hist',x='Names',y='Average')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df3.to_csv('mydf.csv')
